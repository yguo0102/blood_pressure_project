# %%
import pandas as pd

data_file = 'data/BP-Project-List-of-Articles-Somayyeh.xlsx'
df = pd.read_excel(data_file, usecols=['ID', 'DOI', 'Abstract']).dropna(subset=['Abstract'])
df = df[df['Abstract'] != 'NA']
df.to_csv('data/abstract_clean.csv', index=False)
df
# Out:
#       ID                                 DOI  \
# 2      3  10.1161/01.STR.0000014509.11540.66
# 3      4  10.1161/01.str.0000116869.64771.5a
# 4      5                10.1056/nejmoa003417
# 5      6       10.1016/s0140-6736(16)31919-5
# 6      7                     10.1038/nrn1902
# ..   ...                                 ...
# 175  176          10.1016/j.bspc.2018.08.022
# 177  178          10.1016/j.jash.2014.07.034
# 181  182        10.1371/journal.pone.0268934
# 182  183                 10.5194/wes-2022-39
# 183  184           10.1186/s12889-018-6142-x
#
#                                               Abstract
# 2    Background and Purpose— Among patients with ac...
# 3    Background— The last few years have seen a con...
# 4    BACKGROUND Information is limited regarding th...
# 5    Background Raised blood pressure is an importa...
# 6    Key Points There is growing evidence that the ...
# ..                                                 ...
# ...
